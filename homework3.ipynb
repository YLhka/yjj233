# %%
# 1.编写 Python程序,判断输入a是否为质数
def is_prime(a):
    if a <= 1:
        return False
    for i in range(2, int(a**0.5) + 1):
        if a % i == 0:
            return False
    return True

a = int(input("请输入一个整数："))
if is_prime(a):
    print(a, "是质数")
else:
    print(a, "不是质数")
# Out:
# 3 是质数

# %%
# 2.用Python实现插入排序该算法，不允许直接调用插入排序函数，需要手动实现其逻辑过程。
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr
arr=input("请输入一个整数数组，用空格隔开：").split()
arr=[int(i) for i in arr]
print(insertion_sort(arr))
# Out:
# [1, 2, 3]

# %%
# 3.用Python实现选择排序该算法，不允许直接调用选择排序函数，需要手动实现其逻辑过程。
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
arr=input("请输入一个整数数组，用空格隔开：").split()
arr=[int(i) for i in arr]
print(insertion_sort(arr))
# Out:
# [3, 4, 5, 6]

# %%
# 4.用Python实现快速排序该算法，不允许直接调用快速排序函数，需要手动实现其逻辑过程。
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)
    
arr=input("请输入一个整数数组，用空格隔开：").split()
arr=[int(i) for i in arr]
print(insertion_sort(arr))
# Out:
# [2, 3, 5, 6]

# %%
# 5.使用 Python 随机生成三组长度递增的随机数列，长度分别为100、1000、10000，对生成的随机数组使用不同的排序算法，例如选择排序和归并排序，至少三种排序方法。对这些数列的数据排序，并分析不同排序算法在不同长度数列下的运行效果，例如运行时间等指标。（可以使用排序函数）
import random
import time

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

arr11=[]
arr21=[]
arr31=[]
for i in range(100):
    arr11.append(random.randint(1,100))
for i in range(1000):
    arr21.append(random.randint(1,1000))
for i in range(10000):
    arr31.append(random.randint(1,10000))
print(arr11)

arr12=arr11.copy()
arr13=arr11.copy()
arr22=arr21.copy()
arr23=arr21.copy()
arr32=arr31.copy()
arr33=arr31.copy()

start_time = time.time()
insertion_sort(arr11)
print("插入排序运行时间：", time.time() - start_time)
start_time = time.time()
selection_sort(arr12)
print("选择排序运行时间：", time.time() - start_time)
start_time = time.time()
quick_sort(arr13)
print("快速排序运行时间：", time.time() - start_time)
start_time = time.time()
insertion_sort(arr21)
print("插入排序运行时间：", time.time() - start_time)
start_time = time.time()
selection_sort(arr22)
print("选择排序运行时间：", time.time() - start_time)
start_time = time.time()
quick_sort(arr23)
print("快速排序运行时间：", time.time() - start_time)
start_time = time.time()
insertion_sort(arr31)
print("插入排序运行时间：", time.time() - start_time)    
start_time = time.time()
selection_sort(arr32)
print("选择排序运行时间：", time.time() - start_time)    
start_time = time.time()
quick_sort(arr33)
print("快速排序运行时间：", time.time() - start_time)
print(arr11)
# Out:
# [77, 77, 99, 38, 41, 6, 93, 76, 82, 86, 19, 53, 35, 17, 6, 58, 71, 41, 3, 86, 43, 9, 39, 54, 2, 66, 50, 2, 91, 84, 47, 13, 13, 84, 60, 94, 1, 52, 35, 48, 61, 27, 22, 30, 17, 11, 39, 63, 58, 48, 100, 59, 72, 31, 96, 93, 23, 26, 24, 26, 87, 27, 62, 56, 98, 76, 57, 64, 61, 84, 32, 18, 92, 76, 8, 69, 79, 2, 97, 92, 40, 30, 72, 36, 67, 41, 53, 48, 78, 65, 47, 42, 17, 67, 61, 15, 56, 71, 100, 6]
# 插入排序运行时间： 0.0
# 选择排序运行时间： 0.0
# 快速排序运行时间： 0.0
# 插入排序运行时间： 0.012999534606933594
# 选择排序运行时间： 0.013000011444091797
# 快速排序运行时间： 0.001001596450805664
# 插入排序运行时间： 1.2972636222839355
# 选择排序运行时间： 1.2762417793273926
# 快速排序运行时间： 0.013002872467041016
# ...

# %%
# 6.使用python代码获取当前系统时间
import datetime
print(datetime.datetime.now())
# Out:
# 2024-10-24 12:08:05.520445

# %%
# 7.Homework/data文件夹下的stuGrade.csv文件中包含5位同学的学号、语文成绩、数学成绩和英语成绩，请先用记事本打开该文件，查看文件内容，然后编写Python程序，读取该文件，并计算出各科的平均成绩（保留2位小数）。
# 8.请在第7题的代码继续编写Python程序，将以下内容写入my.txt文件中，一并上传到github中。
'''
第1行：你的学号和姓名

第2行：3门课程的平均成绩（任意课程），保留2位小数，以英文逗号间隔

第3行：系统当前时间，格式例如2020-01-01 12:00:00

第4行：两秒后的系统当前时间（利用sleep()方法）
'''
import pandas as pd
import os
import time

# 打印当前工作目录
print("当前工作目录:", os.getcwd())

# 读取文件
try:
    df = pd.read_csv('stuGrade.csv')
except FileNotFoundError as e:
    print(f"文件未找到: {e}")
    exit(1)

# 打印数据框
print(df)

# 计算各科的平均成绩
print('语文成绩平均值：', round(df['chinese'].mean(), 2))
print('数学成绩平均值：', round(df['math'].mean(), 2))
print('英语成绩平均值：', round(df['english'].mean(), 2))
fp=open('my.txt','w')
fp.write('学号：'+input('学号：')+'姓名：'+input('姓名')+'\n')
fp.write('语文成绩平均值：'+str(round(df['chinese'].mean(), 2))+'，数学成绩平均值：'+str(round(df['math'].mean(), 2))+'，英语成绩平均值：'+str(round(df['english'].mean(), 2))+'\n')
fp.write(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())+'\n')
time.sleep(2)
fp.write('两秒后的系统当前时间：'+time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
fp.close()
# Out:
# 当前工作目录: d:\vscode work\导论\yjj233
#    stuID  chinese  math  english
# 0  10381       74    87       82
# 1  10382       92    88       90
# 2  10383       87    82       81
# 3  10384       98    97       96
# 4  10385       62    51       60
# 语文成绩平均值： 82.6
# 数学成绩平均值： 81.0
# 英语成绩平均值： 81.8
